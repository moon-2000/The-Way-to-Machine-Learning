# %% [markdown]
# ## Linear Regression

# %% [raw]
# A linear regression is a linear approximation of a causal relationship between two or more variables.
# This model makes predictions by computing a weighted sum of the input features, plus a constant called the bias/ intercept term.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the first image as a numpy array
img1 = plt.imread("SLR.jpg")

# Load the second image as a numpy array
img2 = plt.imread("SLReq.jpg")

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Display the first image on the left subplot
ax1.imshow(img1)
ax1.axis('off')

# Display the second image on the right subplot
ax2.imshow(img2)
ax2.axis('off')

# Show the figure
plt.show()

# %% [raw]
# To build a machine learning model, you have to follow the following steps:
#     - import relevant libraries
#     - load the cleaned and preprocessed data
#     - build the model
#     - train and optimise the model
#     - test and evaluate the model

# %% [markdown]
# ### Import relevant libraries

# %%
# For these lessons we will need NumPy, pandas, matplotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# and of course the actual regression (machine learning) module
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Load the data

# %%
# We start by loading the data
data = pd.read_csv('1.01. Simple linear regression.csv')

# Let's explore the top 5 rows of the df
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %% [markdown]
# ### Build the model

# %% [markdown]
# #### Declare the dependent and independent variables

# %%
# There is a single independent variable: 'SAT'
x = data['SAT']

# and a single depended variable: 'GPA'
y = data['GPA']

# %%
# Plot the dependent and independent variables
plt.scatter(x, y)

# Add title and axis labels
plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")

# Show the plot
plt.show()

# %%
# Often it is useful to check the shapes of the features
x_shape = x.shape
y_shape = y.shape

print(f"x shape is {x_shape} and y shape is {y_shape}")
# Out:
# x shape is (84,) and y shape is (84,)

# %%
# In order to feed x to sklearn, it should be a 2D array (a matrix)
# Therefore, we must reshape it 
# Note that this will not be needed when we've got more than 1 feature (as the inputs will be a 2D array by default)

# x_matrix = x.values.reshape(84,1)
x_matrix = x.values.reshape(-1,1)

# Check the shape just in case
x_matrix.shape
# Out:
# (84, 1)

# %% [markdown]
# #### Create the linear regression model

# %%
# We start by creating a linear regression object
reg = LinearRegression()

# Note that the first argument is the independent variable, while the second is the dependent 
reg.fit(x_matrix,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaluate the model

# %%
# R-squared measures how well the linear regression model fits the data

# Get the R-squared value
r_squared = reg.score(x_matrix, y)

# Print the R-squared value
print("R-squared:", r_squared)
# Out:
# R-squared: 0.40600391479679765

# %% [markdown]
# ### Test the model

# %%
# Make predictions for new data
X_new = np.array([[1700]])
y_new = reg.predict(X_new)

# Print the predicted values
print(y_new)
# Out:
# [3.08970998]
