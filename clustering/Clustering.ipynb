# %% [raw]
# Clustering is a type of unsupervised learning algorithm in machine learning
#     - that groups similar data points together into clusters.
#     - The goal of clustering is to identify patterns and structures in a dataset without prior knowledge of the groups or labels.
#     - Clustering algorithms can be used for a wide range of applications such as image segmentation, customer segmentation, anomaly detection, and natural language processing.
#
# There are various clustering algorithms, but we will look into K-Means:
#     - K-Means algorithm partitions a dataset into k clusters based on the distance between data points and the centroid of each cluster.

# %% [raw]
# For K-means clustering algorithm, the main steps to apply clustering to a dataset are:
#
# 1- Data preparation:
#     - Load and clean the dataset to be used for clustering.
#     - Preprocess that dataset (if needed), by removing irrelevant features, handling missing values, and scaling the data.
#
# 2- Selection of K:
#     - Determine the number of clusters K to use.
#     - This can be done by analyzing the data, using domain knowledge,
#       or by using methods such as elbow method or silhouette score.
#
# 3- Initialization:
#     - Initialize K cluster centroids either randomly or by using a specific method, such as K-means++.
#     - Cluster assignment:
#         - Assign each data point to the nearest cluster centroid based on the distance metric, typically Euclidean distance.
#     - Recalculation of centroids:
#         - Calculate the new centroid of each cluster by taking the mean of all data points assigned to that cluster.
#
# 4- Repeat until convergence:
#     - Repeat the cluster assignment and centroid recalculation steps
#       until the centroids no longer change or a predefined stopping criterion is reached.
#
# 5- Evaluation of clustering results:
#     - Evaluate the quality of the clusters using external validation metrics such as purity, entropy, or F-measure,..etc.
#
# 6- Visualization and interpretation of results:
#     - Visualize the clustering results to understand the patterns and structure of the clusters.
#     - Interpretation of the results can help to derive insights and make informed decisions based on the findings.
#
# 7- Refinement of K-means:
#     - Based on the evaluation and interpretation of the results, the K-means algorithm may need to be refined
#       by adjusting the value of K, the distance metric used,
#       or by selecting a different algorithm to improve the quality of the clusters.

# %% [markdown]
# ### Import relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set the styles to Seaborn
sns.set()
# Import the KMeans module so we can perform k-means clustering with sklearn
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv('data_clustering.csv')

# Preview data
data.head(3)
# Out:
#             x           y  color
# 0  516.012706  393.014514      0
# 1  436.211762  408.656585      0
# 2  512.052601  372.022014      0

# %%
data.drop('color', axis=1, inplace=True)
# Preview data
data.head(3)
# Out:
#             x           y
# 0  516.012706  393.014514
# 1  436.211762  408.656585
# 2  512.052601  372.022014

# %% [markdown]
# ### Visualize the data

# %%
# plotting the raw data

plt.figure(figsize=(8,6))
plt.scatter(x=data['x'], y=data['y'], s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Unclustered data')
plt.show()

# %% [markdown]
# ### Clustering

# %% [raw]
# Trying Random Rumbers of K, to see how it reflects on the data

# %%
# Apply our k-Means algorithm
model = KMeans(n_clusters=2, n_init='auto')
model.fit(data.values)
preds = model.predict(data.values)

# Plot clusters
plt.figure(figsize=(8,6))
plt.scatter(x=data['x'], y=data['y'], c=preds, cmap='Set1', s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=2)')
plt.show()

# %%
# Apply our k-Means algorithm
model = KMeans(n_clusters=5, n_init='auto')
model.fit(data.values)
preds = model.predict(data.values)

# Plot clusters
plt.figure(figsize=(8,6))
plt.scatter(x=data['x'], y=data['y'], c=preds, cmap='Set1', s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=5)')
plt.show()

# %%
# Apply our k-Means algorithm
model = KMeans(n_clusters=7, n_init='auto')
model.fit(data.values)
preds = model.predict(data.values)

# Plot clusters
plt.figure(figsize=(8,6))
plt.scatter(x=data['x'], y=data['y'], c=preds, cmap='Set1', s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=7)')
plt.show()

# %% [markdown]
# ### Choose the Optimum K using Elbow method

# %%
# define the dependent and independent variables of the data
x = data["x"]
X = x.values.reshape(-1, 1)
y = data["y"]

# %% [raw]
# The elbow method is a popular heuristic for selecting the optimal number of clusters K in K-means clustering.
# It involves plotting the within-cluster sum of squared errors (SSE) against the number of clusters K.
#
# Select the value of K at the "elbow" of the curve, where the SSE starts to level off.

# %%
# This is an aditional line oof code to prevent displaying python warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
km_inertia = []

for k in range(2, 8):
    km = KMeans(k).fit(X)
    km_inertia.append(km.inertia_)
    
clustering_data = pd.DataFrame({'k': range(2, 8), 'score': km_inertia})
sns.lineplot(x='k', y='score', data=clustering_data)
plt.title("Elbow graph of K")
plt.show()

# %% [markdown]
# #### Clustering results

# %% [raw]
# From the above graph, we can see that SSE starts to level off when K is 4

# %%
# Apply our k-Means algorithm with the optimum K value
model = KMeans(n_clusters=4, n_init='auto')
model.fit(data.values)
preds = model.predict(data.values)

# Plot clusters
plt.figure(figsize=(8,6))
plt.scatter(x=data['x'], y=data['y'], c=preds, cmap='Set1', s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=4)')
plt.show()

# %% [raw]
# you can also check how KMeans can be implemented here:
# https://www.kaggle.com/code/samuelcortinhas/k-means-from-scratch?scriptVersionId=105430727&cellId=15
