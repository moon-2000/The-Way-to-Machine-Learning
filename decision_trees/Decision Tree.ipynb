# %% [raw]
# A Decision Tree algorithm is widely used in machine learning and is known for its popularity. It utilizes a tree-like structure with various combinations to solve specific problems.
#
# It falls under the category of supervised learning algorithms and can be used for both classification and regression tasks.
#
# The structure of a Decision Tree algorithm consists of a root node, branches, and leaf nodes. Each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label. The classification rules are represented by the paths from the root node to the leaf node.

# %% [raw]
# There are several terms associated with the Decision Tree algorithm.
#
# Root node:
#     - represents the entire population or sample, which is then divided into two or more sets that are homogeneous or similar in some way.
#
# Splitting:
#     - To divide a node into two or more smaller nodes is known as the process of splitting.
#
# Decision node:
#     - A node becomes a decision node when it splits into multiple sub-nodes.
#
# Leaf/Terminal node:
#     - the nodes in the decision tree that do not split any further.
#
# Pruning:
#     -  the process of removing sub-nodes of a decision node, which aims to reduce the complexity of the tree and prevent overfitting. It is the opposite process of splitting, which involves dividing a node into two or more sub-nodes.
#
# Branch/ Sub-tree:
#     - A segment of the complete tree is referred to as a branch or sub-tree.
#
# Parent & Child node:
#     - A node that is divided into sub-nodes is referred to as the parent node, with the sub-nodes being its children.

# %% [raw]
# Let´s take a look how the decision tree is structured, and with an example helps you to decide whether to accept a job offer or not

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the first image as a numpy array
img1 = plt.imread("decision_tree2.png")

# Load the second image as a numpy array
img2 = plt.imread("decision_tree.png")

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 20))

# Display the first image on the left subplot
ax1.imshow(img1)
ax1.axis('off')

# Display the second image on the right subplot
ax2.imshow(img2)
ax2.axis('off')

# Show the figure
plt.show()

# %% [raw]
# The Decision-Tree algorithm involves certain assumptions during its implementation, which are outlined as follows:
#
# - Initially, the complete training set is taken as the root.
# - The feature values should be categorical in nature. If they are continuous, then they must be transformed into discrete values before constructing the model.
# - The records are recursively distributed based on their attribute values.
# - A statistical approach is employed to determine the placement of attributes as the root or internal node of the tree.

# %% [raw]
# Let´s start seeing the decision tree algorithm on data example

# %% [markdown]
# ###  Import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier

# %%
# to avoid future warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the data

# %%
data = 'data_decisiontree.csv'  # this data is about cars features 

df = pd.read_csv(data, header=None)  # to skip the header raw
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %% [markdown]
# ### Explore the data

# %%
# view dimensions of the dataset
df.shape

# after running the cell, we can see that there are 1728 instances and 7 variables in the data set.
# Out:
# (1728, 7)

# %%
# rename the variables of the dataset
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
df.columns = col_names
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
# get a summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %% [raw]
# The dataset contains 7 variables, all of which are categorical in nature.
#
# These variables are identified as buying, maint, doors, persons, lug_boot, safety, and class,
# with "class" being the target variable.

# %% [markdown]
# ### Preprocess the data

# %%
# check missing values in variables
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %% [raw]
# we can see that there is no missing values in the data

# %%
# determine the dependent and independent variables
X = df.drop(['class'], axis=1)

y = df['class']

# %%
# split X and y into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((1157, 6), (571, 6))

# %% [raw]
# Now, we need to convert the categorical values into numerical ones using categorical encoders

# %%
# import category encoders
import category_encoders as ce

# %%
# encode variables with ordinal encoding
encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])

X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
# let´s see how X_train looks like now
X_train.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 48         1      1      1        1         1       1
# 468        2      1      1        2         2       1
# 155        1      2      1        1         2       2
# 1721       3      3      2        1         2       2
# 1208       4      3      3        1         2       2

# %% [markdown]
# ### Build the model

# %%
# create an instance of the DecisionTreeClassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)

# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
# predict the results of the test set
y_pred_gini = clf_gini.predict(X_test)

# %% [markdown]
# #### Model accuracy

# %%
from sklearn.metrics import accuracy_score

# Here, y_test are the true class labels and y_pred_gini are the predicted class labels in the test-set.
print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.8021

# %%
### Visualize the decision tree on our dataset
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.4, 0.875, 'x[5] <= 1.5\ngini = 0.455\nsamples = 1157\nvalue = [255, 49, 813, 40]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 386\nvalue = [0, 0, 386, 0]'),
#  Text(0.6, 0.625, 'x[3] <= 2.5\ngini = 0.577\nsamples = 771\nvalue = [255, 49, 427, 40]'),
#  Text(0.4, 0.375, 'x[0] <= 2.5\ngini = 0.631\nsamples = 525\nvalue = [255, 49, 181, 40]'),
#  Text(0.2, 0.125, 'gini = 0.496\nsamples = 271\nvalue = [124, 0, 147, 0]'),
#  Text(0.6, 0.125, 'gini = 0.654\nsamples = 254\nvalue = [131, 49, 34, 40]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 246\nvalue = [0, 0, 246, 0]')]

# %% [markdown]
# Now, we are done with the decision tree algorithm!
#
# Try it on another dataset and see how it works by your self.

# %% [markdown]
# Resources:
#     https://www.kaggle.com/code/prashant111/decision-tree-classifier-tutorial#7.-Import-libraries-
